# %% [markdown]
# # 📝 Zepto Dataset - Exploratory Data Analysis (EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("zepto.csv")
df.head()
# Out:
#   Agent Name  Rating                                        Review Text  \
# 0      Zepto     4.5  Purpose boy job cup decision girl now get job ...
# 1      Zepto     2.1  Prevent production able both the box school wa...
# 2    JioMart     4.5  Family station listen agreement more kitchen l...
# 3    JioMart     2.6  World north people area everything enter beyon...
# 4      Zepto     3.6  Hand way yourself tax whether sister anyone ef...
#
#    Delivery Time (min)   Location  Order Type Customer Feedback Type  \
# 0                   58      Delhi  Essentials                Neutral
# 1                   25    Lucknow     Grocery               Negative
# 2                   54  Ahmedabad  Essentials                Neutral
# 3                   22    Chennai  Essentials                Neutral
# 4                   34       Pune    Pharmacy               Positive
#
#   Price Range Discount Applied Product Availability  Customer Service Rating  \
# ...

# %% [markdown]
# ## 1. Basic EDA

# %%
print("\n--- Basic Info ---")
df.info()
# Out:
# --- Basic Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Agent Name               5000 non-null   object
#  1   Rating                   5000 non-null   float64
#  2   Review Text              5000 non-null   object
#  3   Delivery Time (min)      5000 non-null   int64
#  4   Location                 5000 non-null   object
#  5   Order Type               5000 non-null   object
#  6   Customer Feedback Type   5000 non-null   object
#  7   Price Range              5000 non-null   object
#  8   Discount Applied         5000 non-null   object
#  9   Product Availability     5000 non-null   object
#  10  Customer Service Rating  5000 non-null   int64
#  11  Order Accuracy           5000 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 468.9+ KB

# %%
print("\n--- Null Values ---")
df.isnull().sum()
# Out:
# --- Null Values ---
# Agent Name                 0
# Rating                     0
# Review Text                0
# Delivery Time (min)        0
# Location                   0
# Order Type                 0
# Customer Feedback Type     0
# Price Range                0
# Discount Applied           0
# Product Availability       0
# Customer Service Rating    0
# Order Accuracy             0
# dtype: int64

# %%
print("\n--- Summary Statistics ---")
df.describe(include='all')
# Out:
# --- Summary Statistics ---
#        Agent Name      Rating  \
# count        5000  5000.00000
# unique          4         NaN
# top         Zepto         NaN
# freq         1282         NaN
# mean          NaN     3.00290
# std           NaN     1.15214
# min           NaN     1.00000
# 25%           NaN     2.00000
# 50%           NaN     3.00000
# 75%           NaN     4.00000
# max           NaN     5.00000
#
#                                               Review Text  \
# count                                                5000
# unique                                               5000
# top     Agreement challenge boy coach low person these...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# ...

# %% [markdown]
# ## 2. NumPy Questions

# %%
ratings = df['Rating'].values
delivery_times = df['Delivery Time (min)'].values

print("Mean Rating =", np.mean(ratings))
# Out:
# Mean Rating = 3.0029

# %%
print("Median Delivery Time =", np.median(delivery_times))
# Out:
# Median Delivery Time = 35.0

# %%
print("Std Dev of Ratings =", np.std(ratings))
# Out:
# Std Dev of Ratings = 1.1520249953885549

# %%
print("Minimum Rating =", np.min(ratings))
# Out:
# Minimum Rating = 1.0

# %%
print("Unique Delivery Times =", np.unique(delivery_times).size)
# Out:
# Unique Delivery Times = 51

# %%
print("Correlation between Ratings & Delivery Time =", np.corrcoef(ratings, delivery_times)[0,1])
# Out:
# Correlation between Ratings & Delivery Time = 0.006384527268505451

# %% [markdown]
# ## 3. Pandas Questions

# %%
print("\n", df.groupby('Order Type')['Rating'].mean())
# Out:
#  Order Type
# Electronics    3.008135
# Essentials     3.044655
# Food           3.010568
# Grocery        2.954673
# Pharmacy       2.996073
# Name: Rating, dtype: float64

# %%
print("\n", df['Customer Feedback Type'].value_counts())
# Out:
#  Customer Feedback Type
# Negative    1727
# Positive    1648
# Neutral     1625
# Name: count, dtype: int64

# %%
print("\n", df.groupby('Location')['Delivery Time (min)'].max())
# Out:
#  Location
# Ahmedabad    60
# Bangalore    60
# Chennai      60
# Delhi        60
# Hyderabad    60
# Jaipur       60
# Kolkata      60
# Lucknow      60
# Mumbai       60
# Pune         60
# Name: Delivery Time (min), dtype: int64

# %%
print("\n", df.groupby('Agent Name')['Customer Service Rating'].mean().sort_values(ascending=False).head())
# Out:
#  Agent Name
# Blinkit             3.014937
# JioMart             2.973039
# Swiggy Instamart    2.963175
# Zepto               2.936817
# Name: Customer Service Rating, dtype: float64

# %%
print("Avg Delivery Time per Order Type\n", df.groupby('Order Type')['Delivery Time (min)'].mean())
# Out:
# Avg Delivery Time per Order Type
#  Order Type
# Electronics    35.270833
# Essentials     35.287712
# Food           34.684945
# Grocery        35.283417
# Pharmacy       34.279960
# Name: Delivery Time (min), dtype: float64

# %%
print("Most Common Location =", df['Location'].mode()[0])
# Out:
# Most Common Location = Kolkata

# %%
print("Incorrect Orders =", (df['Order Accuracy'].eq('Incorrect').mean()) * 100)
# Out:
# Incorrect Orders = 49.7

# %%
print("Orders with Discount & Rating>4\n", df[(df['Discount Applied']=='Yes') & (df['Rating']>4)].head())
# Out:
# Orders with Discount & Rating>4
#            Agent Name  Rating  \
# 0              Zepto     4.5
# 18           JioMart     4.7
# 42           Blinkit     4.3
# 43             Zepto     4.7
# 54  Swiggy Instamart     4.6
#
#                                           Review Text  Delivery Time (min)  \
# 0   Purpose boy job cup decision girl now get job ...                   58
# 18  Individual politics price necessary Republican...                   51
# 42    Occur season measure a mother thing bring life.                   38
# 43  Dog letter probably bar reality indeed place s...                   38
# 54  Company mean somebody suggest rich itself prog...                   50
#
#      Location  Order Type Customer Feedback Type Price Range Discount Applied  \
# 0       Delhi  Essentials                Neutral        High              Yes
# 18    Kolkata  Essentials               Negative        High              Yes
# ...

# %% [markdown]
# ## 4. Matplotlib Visualizations

# %%
plt.hist(ratings, bins=20, edgecolor='black')
plt.title('Histogram of Ratings')
# Out:
# Text(0.5, 1.0, 'Histogram of Ratings')

# %%
df['Order Type'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.title('Order Type Distribution')
# Out:
# Text(0.5, 1.0, 'Order Type Distribution')

# %%
df['Customer Feedback Type'].value_counts().plot(kind='bar')
plt.title('Customer Feedback Type')
# Out:
# Text(0.5, 1.0, 'Customer Feedback Type')

# %%
plt.plot(df['Delivery Time (min)'].head(50))
plt.grid(True)
plt.title('Delivery Times (First 50 Orders)')
# Out:
# Text(0.5, 1.0, 'Delivery Times (First 50 Orders)')

# %%
plt.scatter(df['Delivery Time (min)'], df['Rating'], alpha=0.5)
plt.xlabel('Delivery Time (min)')
plt.ylabel('Rating')
plt.title('Scatter: Delivery Time vs Rating')
# Out:
# Text(0.5, 1.0, 'Scatter: Delivery Time vs Rating')

# %% [markdown]
# ## 5.Seaborn Visualizations

# %%
feedback_price = pd.crosstab(df['Price Range'], df['Customer Feedback Type'])
feedback_price.plot(kind='bar', stacked=True, ax=plt.gca())
plt.title('Stacked Bar: Feedback vs Price Range')
# Out:
# Text(0.5, 1.0, 'Stacked Bar: Feedback vs Price Range')

# %%
sns.scatterplot(x='Delivery Time (min)', y='Rating', data=df)
plt.title('Scatter: Delivery Time vs Rating')
# Out:
# Text(0.5, 1.0, 'Scatter: Delivery Time vs Rating')

# %%
sns.lineplot(x=range(50), y=df['Rating'].head(50) ,marker='o', color='blue')
plt.title('Line Plot of Ratings (First 50)')
# Out:
# Text(0.5, 1.0, 'Line Plot of Ratings (First 50)')

# %%
sns.barplot(x='Order Type', y='Rating', data=df)
plt.title('Bar: Order Type vs Rating')
# Out:
# Text(0.5, 1.0, 'Bar: Order Type vs Rating')

# %%
sns.boxplot(x='Price Range', y='Rating', data=df)
plt.title('Box: Price Range vs Rating')
# Out:
# Text(0.5, 1.0, 'Box: Price Range vs Rating')

# %%
sns.violinplot(x='Discount Applied', y='Delivery Time (min)', data=df)
plt.title('Violin: Discount vs Delivery Time')
# Out:
# Text(0.5, 1.0, 'Violin: Discount vs Delivery Time')

# %%
sns.countplot(x='Customer Feedback Type', data=df,palette='pastel')
plt.title('Count: Feedback Types')
# Out:
# C:\Users\l\AppData\Local\Temp\ipykernel_18300\2555611778.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Customer Feedback Type', data=df,palette='pastel')
# Text(0.5, 1.0, 'Count: Feedback Types')

# %%
sns.kdeplot(ratings ,  fill=True, color='purple')
plt.grid(True)
plt.title('KDE Plot of Ratings')
# Out:
# Text(0.5, 1.0, 'KDE Plot of Ratings')

# %%
sns.histplot(ratings, kde=True ,  color='coral')
plt.title('Distribution Plot of Ratings')
# Out:
# Text(0.5, 1.0, 'Distribution Plot of Ratings')
